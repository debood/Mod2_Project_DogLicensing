# %%
import pandas as pd

df = pd.read_csv("Data/Cleaned/final_dataset.csv")
df.head()
df.columns.tolist()
df.shape
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# AnimalName            1321
# DogAgeGroup            343
# ApproxDogAge            97
# AnimalGender             0
# AnimalBirthYear          0
# BreedName                0
# ZipCode                  0
# LicenseIssuedDate        0
# LicenseExpiredDate       0
# Extract Year             0
# IssueYear                0
# ExpireYear               0
# IsBadName                0
# CleanedBreedName         0
# dtype: int64

# %%
year_counts = (
    df.groupby("IssueYear")
      .size()
      .reset_index(name="license_count")
      .sort_values("IssueYear")
)
year_counts.head()
# Out:
#    IssueYear  license_count
# 0       2014           1535
# 1       2015          34371
# 2       2016          76360
# 3       2017          73584
# 4       2018          71757

# %%
older_dogs = df[df["DogAgeGroup"].isin(["7–10 (Senior)", "10+ (Elderly)"])]
older_dogs
# Out:
#        AnimalName AnimalGender  AnimalBirthYear  \
# 20           OTIS            F           2001.0
# 23          LOGAN            M           2003.0
# 66          ANGEL            M           2000.0
# 68        SABRINA            F           2002.0
# 77         JUPLAY            M           2002.0
# ...           ...          ...              ...
# 546670     POGACS            F           2010.0
# 546671     BRUTUS            M           2013.0
# 546673       RUBY            F           2013.0
# 546675       FRED            M           2010.0
# 546715      SALLY            F           2013.0
#
#                                    BreedName  ZipCode LicenseIssuedDate  \
# 20                                   Unknown    10011        2014-09-13
# 23                                   Unknown    10011        2014-09-13
# 66                              Bichon Frise    10467        2014-09-15
# 68                                   Unknown    11106        2014-09-16
# ...
